# %%
pip install spotipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credentials_manager = SpotifyClientCredentials(client_id="ac1189bfa89c4c1691c74c99bb2c247a" ,client_secret="81fa2c6b95224e6c901c585c28f9e4a8")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/6VOedaf3eNWDOVpa9Qdlvg"

# %%
playlist_url = playlist_link.split('/')[-1].split('?')[0]

# %%
data = sp.playlist_tracks(playlist_url)

# %%
data['items']
# Out:
# [{'added_at': '2025-03-07T07:49:17Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31rzz7jr6t3e3mqgitwppkmfg2ve'},
#    'href': 'https://api.spotify.com/v1/users/31rzz7jr6t3e3mqgitwppkmfg2ve',
#    'id': '31rzz7jr6t3e3mqgitwppkmfg2ve',
#    'type': 'user',
#    'uri': 'spotify:user:31rzz7jr6t3e3mqgitwppkmfg2ve'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
# ...

# %%
len(data['items'])
# Out:
# 79

# %%
data['items'][0]['track']['album']
# Out:
# {'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
# ...

# %%
data['items'][0]['track']['album']['id']
# Out:
# '6xUYw5goKIoyJQi9C27UBy'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'NUNCA MUDA?'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2025-01-09'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 6

# %%
data['items'][0]['track']['album']['external_urls']
# Out:
# {'spotify': 'https://open.spotify.com/album/6xUYw5goKIoyJQi9C27UBy'}

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/6xUYw5goKIoyJQi9C27UBy'

# %%
album_list=[]
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id' : album_id,'name':album_name , 'release_date' :album_release_date ,'total_tracks':album_total_tracks,
    'album_url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '6xUYw5goKIoyJQi9C27UBy',
#   'name': 'NUNCA MUDA?',
#   'release_date': '2025-01-09',
#   'total_tracks': 6,
#   'album_url': 'https://open.spotify.com/album/6xUYw5goKIoyJQi9C27UBy'},
#  {'album_id': '0I7096R74VFP2xnMmp33sY',
#   'name': 'PASSO BEM SOLTO',
#   'release_date': '2024-04-23',
#   'total_tracks': 5,
#   'album_url': 'https://open.spotify.com/album/0I7096R74VFP2xnMmp33sY'},
#  {'album_id': '4s7LxMlh6RxgdMhldfMe8u',
#   'name': 'Funk de Beleza',
#   'release_date': '2024-10-04',
#   'total_tracks': 3,
#   'album_url': 'https://open.spotify.com/album/4s7LxMlh6RxgdMhldfMe8u'},
#  {'album_id': '3bT53CJPMsSXSn0vDAX2Do',
#   'name': 'DIA DELÍCIA',
#   'release_date': '2025-04-25',
#   'total_tracks': 4,
#   'album_url': 'https://open.spotify.com/album/3bT53CJPMsSXSn0vDAX2Do'},
#  {'album_id': '5fvUS8yHMCkTZj4sJ0FHDV',
#   'name': 'Vem Vem',
#   'release_date': '2025-05-30',
#   'total_tracks': 4,
# ...

# %%
artists_list =[]
for row in data['items']:
    for key,value in row.items():
        if key == 'track':
            for artist in value['artists']:
                artist_dict ={'artists_id':artist['id'], 'artists_name':artist['name'], 'external_url':artist['href']}
                artists_list.append(artist_dict)

# %%
artists_list
# Out:
# [{'artists_id': '5dDNNq04RjKXFOADdHd6VX',
#   'artists_name': 'Scythermane',
#   'external_url': 'https://api.spotify.com/v1/artists/5dDNNq04RjKXFOADdHd6VX'},
#  {'artists_id': '7lAaAGxYxk2GH8cMbTEwAL',
#   'artists_name': 'NXGHT!',
#   'external_url': 'https://api.spotify.com/v1/artists/7lAaAGxYxk2GH8cMbTEwAL'},
#  {'artists_id': '14hsjenLEdvafsGkk2CEiF',
#   'artists_name': 'MC Fabinho da Osk',
#   'external_url': 'https://api.spotify.com/v1/artists/14hsjenLEdvafsGkk2CEiF'},
#  {'artists_id': '5SCDfg1YoEfI5gFtXqEWah',
#   'artists_name': 'ATLXS',
#   'external_url': 'https://api.spotify.com/v1/artists/5SCDfg1YoEfI5gFtXqEWah'},
#  {'artists_id': '3g0UoyvaTaHUrfpHiRqsD1',
#   'artists_name': 'Nateki',
#   'external_url': 'https://api.spotify.com/v1/artists/3g0UoyvaTaHUrfpHiRqsD1'},
#  {'artists_id': '5dDNNq04RjKXFOADdHd6VX',
#   'artists_name': 'Scythermane',
#   'external_url': 'https://api.spotify.com/v1/artists/5dDNNq04RjKXFOADdHd6VX'},
#  {'artists_id': '10mKIVPFtg42JIvttHQrzr',
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '5EIjpM1B1VsLoKvv2iwd0P',
#   'song_name': 'NUNCA MUDA?',
#   'duration_ms': 81500,
#   'url': 'https://open.spotify.com/track/5EIjpM1B1VsLoKvv2iwd0P',
#   'popularity': 76,
#   'song_added': '2025-03-07T07:49:17Z',
#   'album_id': '6xUYw5goKIoyJQi9C27UBy',
#   'artist_id': '5dDNNq04RjKXFOADdHd6VX'},
#  {'song_id': '4sTlQPMyoFMPdhAJvErBN3',
#   'song_name': 'PASSO BEM SOLTO - Slowed',
#   'duration_ms': 116072,
#   'url': 'https://open.spotify.com/track/4sTlQPMyoFMPdhAJvErBN3',
#   'popularity': 85,
#   'song_added': '2025-05-10T16:34:06Z',
#   'album_id': '0I7096R74VFP2xnMmp33sY',
#   'artist_id': '5SCDfg1YoEfI5gFtXqEWah'},
#  {'song_id': '43jExF2HeZ6cJIGrWF0ie4',
#   'song_name': 'Funk de Beleza - Slowed',
#   'duration_ms': 145115,
#   'url': 'https://open.spotify.com/track/43jExF2HeZ6cJIGrWF0ie4',
#   'popularity': 77,
#   'song_added': '2025-03-07T07:49:21Z',
#   'album_id': '4s7LxMlh6RxgdMhldfMe8u',
#   'artist_id': '3g0UoyvaTaHUrfpHiRqsD1'},
# ...

# %%
album_df =pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id             name release_date  total_tracks  \
# 0  6xUYw5goKIoyJQi9C27UBy      NUNCA MUDA?   2025-01-09             6
# 1  0I7096R74VFP2xnMmp33sY  PASSO BEM SOLTO   2024-04-23             5
# 2  4s7LxMlh6RxgdMhldfMe8u   Funk de Beleza   2024-10-04             3
# 3  3bT53CJPMsSXSn0vDAX2Do      DIA DELÍCIA   2025-04-25             4
# 4  5fvUS8yHMCkTZj4sJ0FHDV          Vem Vem   2025-05-30             4
#
#                                            album_url
# 0  https://open.spotify.com/album/6xUYw5goKIoyJQi...
# 1  https://open.spotify.com/album/0I7096R74VFP2xn...
# 2  https://open.spotify.com/album/4s7LxMlh6RxgdMh...
# 3  https://open.spotify.com/album/3bT53CJPMsSXSn0...
# 4  https://open.spotify.com/album/5fvUS8yHMCkTZj4...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 78 entries, 0 to 78
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   album_id       78 non-null     object
#  1   name           78 non-null     object
#  2   release_date   78 non-null     datetime64[ns]
#  3   total_tracks   78 non-null     int64
#  4   album_url      78 non-null     object
#  5   ;release_date  78 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 4.3+ KB

# %%
album_df['release_date'] =pd.to_datetime(album_df['release_date'])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13644\91995963.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   album_df['release_date'] =pd.to_datetime(album_df['release_date'])

# %%
album_df=album_df.drop_duplicates(subset=['album_id'])

# %%
artists_df=pd.DataFrame.from_dict(artists_list)

# %%
artists_df = artists_df.drop_duplicates(subset=['artists_id'])

# %%
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df = song_df.drop_duplicates(subset=['song_id'])

# %%
song_df.head()
# Out:
#                   song_id                 song_name  duration_ms  \
# 0  5EIjpM1B1VsLoKvv2iwd0P               NUNCA MUDA?        81500
# 1  4sTlQPMyoFMPdhAJvErBN3  PASSO BEM SOLTO - Slowed       116072
# 2  43jExF2HeZ6cJIGrWF0ie4   Funk de Beleza - Slowed       145115
# 3  094IjHeVUviN4aBnSXYsuj               DIA DELÍCIA        75461
# 4  2FnkrCrbXJuebXxnVtXiHI                   Vem Vem        83183
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/5EIjpM1B1VsLoKv...          76
# 1  https://open.spotify.com/track/4sTlQPMyoFMPdhA...          85
# 2  https://open.spotify.com/track/43jExF2HeZ6cJIG...          77
# 3  https://open.spotify.com/track/094IjHeVUviN4aB...          86
# 4  https://open.spotify.com/track/2FnkrCrbXJuebXx...          83
#
#              song_added                album_id               artist_id
# 0  2025-03-07T07:49:17Z  6xUYw5goKIoyJQi9C27UBy  5dDNNq04RjKXFOADdHd6VX
# ...

# %%
song_df['song_added']= pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      79 non-null     object
#  1   song_name    79 non-null     object
#  2   duration_ms  79 non-null     int64
#  3   url          79 non-null     object
#  4   popularity   79 non-null     int64
#  5   song_added   79 non-null     datetime64[ns, UTC]
#  6   album_id     79 non-null     object
#  7   artist_id    79 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 5.1+ KB

# %%
album_df.loc[:, 'release_date'] = pd.to_datetime(album_df['release_date'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 78 entries, 0 to 78
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   album_id       78 non-null     object
#  1   name           78 non-null     object
#  2   release_date   78 non-null     datetime64[ns]
#  3   total_tracks   78 non-null     int64
#  4   album_url      78 non-null     object
#  5   ;release_date  78 non-null     datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 4.3+ KB
